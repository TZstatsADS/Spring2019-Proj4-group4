# %%
import os
import pandas as pd
import numpy as np
import pickle
import warnings
import json
from matplotlib import pyplot as plt
warnings.filterwarnings('ignore')

# %% [markdown]
# # Text Preprocessing
# **Create the directories**

# %%
tesseract_files = os.listdir('../data/tesseract')
gtruth_files = os.listdir('../data/ground_truth')

# %%
for i in range(len(gtruth_files)):
    gtruth_files[i] = '../data/ground_truth/'+ gtruth_files[i]
for j in range(len(tesseract_files)):
    tesseract_files[j] = '../data/tesseract/'+ tesseract_files[j]

# %% [markdown]
# We filtered out the lines with unequal length. There are 175496 tokens in total.

# %%
ocr_tokens = []
ground_tokens = []
labels = []
doc_id = []

id_num=0
for g, t in zip(gtruth_files, tesseract_files):
    with open(g) as file1:
        with open(t) as file2:
            id_num+=1
            for line1,line2 in zip(file1, file2):
                if len(line1) == len(line2):
                    for word1, word2 in zip(line1.split(), line2.split()):
                        ground_tokens.append(word1)
                        ocr_tokens.append(word2)
                        doc_id.append(id_num)
                        labels.append(0) if word1==word2 else labels.append(1)

# %%
df = pd.DataFrame(data={"doc_id":doc_id, "ocr_tokens": ocr_tokens, "correct_tokens": ground_tokens, "labels": labels})
df.head()
# Out:
#    doc_id      ocr_tokens  correct_tokens  labels
# 0       1  communlcatlons  communications       1
# 1       1        network.        network.       0
# 2       1          Member          Member       0
# 3       1       companles       companies       1
# 4       1             are             are       0

# %%
# df.to_csv("../output/processed_tokens.csv", sep=',',index=False)

# %% [markdown]
# **Build a word count frequency dictionary**

# %%
# truth_dic = {}

# # read in all the ground truth files into a dictionary
# for file_name in gtruth_files:
#     with open(file_name) as ground_file:
#         ground_raw = ground_file.read()  # a string
#         tokens = ground_raw.split()
#         for tok in tokens:
#             if tok in truth_dic:
#                 truth_dic.update({tok: truth_dic[tok]+1})
#             else:
#                 truth_dic.update({tok: 1})

# %%
# with open('../output/ground_truth_word_count.json','w') as f:
#     json.dump(truth_dic, f)

# %% [markdown]
# **Feature generation in R**
#
# output a file "features.csv".

# %% [markdown]
# # SVM

# %% [markdown]
# Load features

# %%
features = pd.read_csv("../output/features.csv")
features.head()
# Out:
#    Unnamed: 0          tokens  labels  feature 1  feature 2  feature 3  \
# 0           1  communlcatlons       1         14   0.285714   0.714286
# 1           2        network.       0          8   0.250000   0.625000
# 2           3          Member       0          6   0.333333   0.666667
# 3           4       companles       1          9   0.333333   0.666667
# 4           5             are       0          3   0.666667   0.333333
#
#    feature 4  feature 5  feature 6  feature 7  feature 8  feature 9  \
# 0   0.396040      0.000        0.0   1.000000   0.000000        0.0
# 1   0.392157      0.125        0.0   0.875000   0.000000        0.0
# 2   0.487805      0.000        0.0   0.833333   0.166667        0.0
# 3   0.491803      0.000        0.0   1.000000   0.000000        0.0
# 4   1.818182      0.000        0.0   1.000000   0.000000        0.0
#
#    feature 10  feature 11  feature 12  feature 13
# 0           0           0           1    0.570100
# 1           0           0           1    0.261057
# 2           0           0           1    0.538740
# 3           0           0           1    0.672950
# 4           0           0           1    1.137650

# %%
# features.isnull().sum()

# %%
features[['feature 13']] = features[['feature 13']].fillna(0)
features.shape
# Out:
# (298728, 16)

# %%
# normalize data
from sklearn.preprocessing import StandardScaler
from sklearn import model_selection
from sklearn.model_selection import GridSearchCV

scaler = StandardScaler()

X = features.iloc[:,3:]
X = scaler.fit_transform(X)
y = features[['labels']]
print ("Feature space holds %d observations and %d features" % X.shape)
print ("Unique target labels:", np.unique(y))
# Out:
# Feature space holds 298728 observations and 13 features
# Unique target labels: [0 1]

# %%
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=0.2)

print('training data has %d observation with %d features'% X_train.shape)
print('test data has %d observation with %d features'% X_test.shape)
# Out:
# training data has 238982 observation with 13 features
# test data has 59746 observation with 13 features

# %%
def print_grid_search_metrics(gs):
    print ("Best score: %0.3f" % gs.best_score_)
    print ("Best parameters set:")
    best_parameters = gs.best_params_
    for param_name in sorted(parameters.keys()):
        print("\t%s: %r" % (param_name, best_parameters[param_name]))

# %% [markdown]
# Train a subset

# %%
svm_model = SVC(kernel='rbf')
svm_model.fit(X_train, y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=None,
#   shrinking=True, tol=0.001, verbose=False)

# %%
# from sklearn.svm import SVC

# parameters = {
# #     'C':(0.25, 0.75, 1, 1.25, 1.5, 2),
#     'C':(0.25, 0.75, 1),
#     'kernel': ('rbf','linear'),
# }
# Grid_SVM = GridSearchCV(SVC(), parameters, cv=5)
# Grid_SVM.fit(X_train, y_train)

# %%
# print_grid_search_metrics(Grid_LR)

# %%
# best_SVM_model = Grid_LR.best_estimator_

# %%
path = '../output/svm_model.pkl'
# pickle.dump(svm_model, open(path, 'wb'))

# %%
saved_svm_model = pickle.load(open(path, 'rb'))
saved_svm_model
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=None,
#   shrinking=True, tol=0.001, verbose=False)

# %% [markdown]
# # Model Evaluation

# %%
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score

def cal_evaluation(classifier, cm):
    tn = cm[0][0]
    fp = cm[0][1]
    fn = cm[1][0]
    tp = cm[1][1]
    accuracy  = (tp + tn) / (tp + fp + fn + tn + 0.0)
    precision = tp / (tp + fp + 0.0)
    recall = tp / (tp + fn + 0.0)
    print (classifier)
    print ("Accuracy is: %0.3f" % accuracy)
    print ("precision is: %0.3f" % precision)
    print ("recall is: %0.3f" % recall)

def draw_confusion_matrix(cm):
    class_names = ['Correct_Output','Incorrect_OCR_Output']
    
    classifier, cm = cm[0], cm[1]
    cal_evaluation(classifier, cm)
    fig = plt.figure()
    ax = fig.add_subplot(111)
    cax = ax.matshow(cm, interpolation='nearest',cmap=plt.get_cmap('Reds'))
    plt.title('Confusion matrix for %s' % classifier)
    fig.colorbar(cax)
    ax.set_xticklabels([''] + class_names)
    ax.set_yticklabels([''] + class_names)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()

# %%
# %matplotlib inline

cm = ["SVM", confusion_matrix(y_test,svm_model.predict(X_test))]

draw_confusion_matrix(cm)
# Out:
# SVM
# Accuracy is: 0.848
# precision is: 0.859
# recall is: 0.654

# %%
y_test
features.head()
# Out:
#    Unnamed: 0          tokens  labels  feature 1  feature 2  feature 3  \
# 0           1  communlcatlons       1         14   0.285714   0.714286
# 1           2        network.       0          8   0.250000   0.625000
# 2           3          Member       0          6   0.333333   0.666667
# 3           4       companles       1          9   0.333333   0.666667
# 4           5             are       0          3   0.666667   0.333333
#
#    feature 4  feature 5  feature 6  feature 7  feature 8  feature 9  \
# 0   0.396040      0.000        0.0   1.000000   0.000000        0.0
# 1   0.392157      0.125        0.0   0.875000   0.000000        0.0
# 2   0.487805      0.000        0.0   0.833333   0.166667        0.0
# 3   0.491803      0.000        0.0   1.000000   0.000000        0.0
# 4   1.818182      0.000        0.0   1.000000   0.000000        0.0
#
#    feature 10  feature 11  feature 12  feature 13
# 0           0           0           1    0.570100
# 1           0           0           1    0.261057
# 2           0           0           1    0.538740
# 3           0           0           1    0.672950
# 4           0           0           1    1.137650

# %%
# features[['tokens']].loc[y_test.index]

# %% [markdown]
# # Output the detected error for correction

# %%
y_pred = saved_svm_model.predict(X)

# %%
# features[['tokens','labels']].loc[y_pred==1]
detected_error = features[['tokens']].loc[y_pred==1]
detected_error.head()
# Out:
#             tokens
# 0   communlcatlons
# 5         strongly
# 9             thls
# 16       1nclud1ng
# 25        1nvolved

# %%
# get doc_id and ocr_output from ocr_output.csv file
svm_output = pd.DataFrame(data={'doc_id':doc_id, 'tokens':ocr_output, 'predicted':y_pred, 'ground_truth':labels})
svm_output.to_csv("../output/svm_output.csv", sep=',',index=False)

# %%
svm_output.shape
# Out:
# (298728, 4)

# %%
svm_output
# Out:
#         doc_id          tokens  predicted  ground_truth
# 0            1  communlcatlons          1             1
# 1            1        network.          0             0
# 2            1          Member          0             0
# 3            1       companles          0             1
# 4            1             are          0             0
# 5            1        strongly          1             0
# 6            1      encouraged          0             0
# 7            1              to          0             0
# 8            1         provlde          0             1
# 9            1            thls          1             1
# 10           1          needed          0             0
# 11           1        support.          0             0
# 12           1             The          0             0
# 13           1           state          0             0
# 14           1        advocacy          0             0
# 15           1        program"          0             0
# 16           1       1nclud1ng          1             1
# 17           1             the          0             0
# 18           1             new          0             0
# 19           1        CMA/LINC          0             0
# 20           1        computer          0             0
# 21           1        network.          0             0
# 22           1            will          0             0
# 23           1              be          0             0
# 24           1         heavlly          0             1
# 25           1        1nvolved          1             1
# 26           1              1n          1             1
# 27           1            1995          1             0
# 28           1              1n          1             1
# 29           1             the          0             0
# ...        ...             ...        ...           ...
# 298698     100              be          0             0
# 298699     100     coordlnated          1             1
# 298700     100              mm          1             1
# 298701     100           those          0             0
# 298702     100              of          0             0
# 298703     100             the          0             0
# 298704     100   Internatlonal          1             1
# 298705     100         Chamber          0             0
# 298706     100              of          0             0
# 298707     100        Commerce          0             0
# 298708     100             and          0             0
# 298709     100             the          0             0
# 298710     100        European          0             0
# 298711     100         Councll          0             1
# 298712     100              of          0             0
# 298713     100        Chemlcal          1             1
# 298714     100  Manufacturers'          1             0
# 298715     100    Federatlons.          1             1
# 298716     100         Patents          0             0
# 298717     100             and          0             0
# 298718     100      Protectlon          1             1
# 298719     100              of          0             0
# 298720     100      Technology          1             0
# 298721     100        Congress          0             0
# 298722     100            Page          0             0
# 298723     100              cm          1             1
# 298724     100          039544          1             1
# 298725     100         Process          0             0
# 298726     100          Patent          0             0
# 298727     100    Leglslatlon.          1             1
#
# [298728 rows x 4 columns]
